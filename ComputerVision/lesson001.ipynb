# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('data/img/img01.png')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)  # OpenCV usa BGR, matplotlib usa RGB
plt.imshow(img_rgb)
plt.axis('off')
plt.show()

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt") 

# Predict on an image
results = model("../bus.jpg")
results[0].show()
# Out:
# image 1/1 c:\Users\DomingosCesar\Documents\GitHub\aiml\ComputerVision\..\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 631.5ms
# Speed: 10.1ms preprocess, 631.5ms inference, 4.4ms postprocess per image at shape (1, 3, 640, 480)

# %%
# !pip install ipykernel -U --force-reinstall
# Out:
# Collecting ipykernel
#   Obtaining dependency information for ipykernel from https://files.pythonhosted.org/packages/82/b9/e73d5d9f405cba7706c539aa8b311b49d4c2f3d698d9c12f815231169c71/ipykernel-7.2.0-py3-none-any.whl.metadata
#   Using cached ipykernel-7.2.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting comm>=0.1.1 (from ipykernel)
#   Obtaining dependency information for comm>=0.1.1 from https://files.pythonhosted.org/packages/60/97/891a0971e1e4a8c5d2b20bbe0e524dc04548d2307fee33cdeba148fd4fc7/comm-0.2.3-py3-none-any.whl.metadata
#   Using cached comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy>=1.6.5 (from ipykernel)
#   Obtaining dependency information for debugpy>=1.6.5 from https://files.pythonhosted.org/packages/a1/39/2bef246368bd42f9bd7cba99844542b74b84dacbdbea0833e610f384fee8/debugpy-1.8.20-cp312-cp312-win_amd64.whl.metadata
#   Using cached debugpy-1.8.20-cp312-cp312-win_amd64.whl.metadata (1.5 kB)
# Collecting ipython>=7.23.1 (from ipykernel)
#   Obtaining dependency information for ipython>=7.23.1 from https://files.pythonhosted.org/packages/59/22/906c8108974c673ebef6356c506cebb6870d48cedea3c41e949e2dd556bb/ipython-9.12.0-py3-none-any.whl.metadata
#   Using cached ipython-9.12.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyter-client>=8.8.0 (from ipykernel)
#   Obtaining dependency information for jupyter-client>=8.8.0 from https://files.pythonhosted.org/packages/2d/0b/ceb7694d864abc0a047649aec263878acb9f792e1fec3e676f22dc9015e3/jupyter_client-8.8.0-py3-none-any.whl.metadata
#   Using cached jupyter_client-8.8.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyter-core!=6.0.*,>=5.1 (from ipykernel)
#   Obtaining dependency information for jupyter-core!=6.0.*,>=5.1 from https://files.pythonhosted.org/packages/e7/e7/80988e32bf6f73919a113473a604f5a8f09094de312b9d52b79c2df7612b/jupyter_core-5.9.1-py3-none-any.whl.metadata
#   Using cached jupyter_core-5.9.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting matplotlib-inline>=0.1 (from ipykernel)
#   Obtaining dependency information for matplotlib-inline>=0.1 from https://files.pythonhosted.org/packages/af/33/ee4519fa02ed11a94aef9559552f3b17bb863f2ecfe1a35dc7f548cde231/matplotlib_inline-0.2.1-py3-none-any.whl.metadata
#   Using cached matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting nest-asyncio>=1.4 (from ipykernel)
#   Obtaining dependency information for nest-asyncio>=1.4 from https://files.pythonhosted.org/packages/a0/c4/c2971a3ba4c6103a3d10c4b0f24f461ddc027f0f09763220cf35ca1401b3/nest_asyncio-1.6.0-py3-none-any.whl.metadata
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting packaging>=22 (from ipykernel)
#   Obtaining dependency information for packaging>=22 from https://files.pythonhosted.org/packages/b7/b9/c538f279a4e237a006a2c98387d081e9eb060d203d8ed34467cc0f0b9b53/packaging-26.0-py3-none-any.whl.metadata
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting psutil>=5.7 (from ipykernel)
#   Obtaining dependency information for psutil>=5.7 from https://files.pythonhosted.org/packages/b4/90/e2159492b5426be0c1fef7acba807a03511f97c5f86b3caeda6ad92351a7/psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata
#   Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl.metadata (22 kB)
# Collecting pyzmq>=25 (from ipykernel)
#   Obtaining dependency information for pyzmq>=25 from https://files.pythonhosted.org/packages/fc/7f/a21b20d577e4100c6a41795842028235998a643b1ad406a6d4163ea8f53e/pyzmq-27.1.0-cp312-abi3-win_amd64.whl.metadata
#   Using cached pyzmq-27.1.0-cp312-abi3-win_amd64.whl.metadata (6.0 kB)
# Collecting tornado>=6.4.1 (from ipykernel)
#   Obtaining dependency information for tornado>=6.4.1 from https://files.pythonhosted.org/packages/2c/23/f6c6112a04d28eed765e374435fb1a9198f73e1ec4b4024184f21faeb1ad/tornado-6.5.5-cp39-abi3-win_amd64.whl.metadata
#   Using cached tornado-6.5.5-cp39-abi3-win_amd64.whl.metadata (2.9 kB)
# Collecting traitlets>=5.4.0 (from ipykernel)
#   Obtaining dependency information for traitlets>=5.4.0 from https://files.pythonhosted.org/packages/00/c0/8f5d070730d7836adc9c9b6408dec68c6ced86b304a9b26a14df072a6e8c/traitlets-5.14.3-py3-none-any.whl.metadata
#   Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting colorama>=0.4.4 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for colorama>=0.4.4 from https://files.pythonhosted.org/packages/d1/d6/3965ed04c63042e047cb6a3e6ed1a63a35087b6a609aa3a15ed8ac56c221/colorama-0.4.6-py2.py3-none-any.whl.metadata
#   Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting decorator>=5.1.0 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for decorator>=5.1.0 from https://files.pythonhosted.org/packages/4e/8c/f3147f5c4b73e7550fe5f9352eaa956ae838d5c51eb58e7a25b9f3e2643b/decorator-5.2.1-py3-none-any.whl.metadata
#   Using cached decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers>=1.0.0 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for ipython-pygments-lexers>=1.0.0 from https://files.pythonhosted.org/packages/d9/33/1f075bf72b0b747cb3288d011319aaf64083cf2efef8354174e3ed4540e2/ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata
#   Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.18.2 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for jedi>=0.18.2 from https://files.pythonhosted.org/packages/c0/5a/9cac0c82afec3d09ccd97c8b6502d48f165f9124db81b4bcb90b4af974ee/jedi-0.19.2-py2.py3-none-any.whl.metadata
#   Using cached jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for prompt_toolkit<3.1.0,>=3.0.41 from https://files.pythonhosted.org/packages/84/03/0d3ce49e2505ae70cf43bc5bb3033955d2fc9f932163e84dc0779cc47f48/prompt_toolkit-3.0.52-py3-none-any.whl.metadata
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.14.0 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for pygments>=2.14.0 from https://files.pythonhosted.org/packages/f4/7e/a72dd26f3b0f4f2bf1dd8923c85f7ceb43172af56d63c7383eb62b332364/pygments-2.20.0-py3-none-any.whl.metadata
#   Using cached pygments-2.20.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data>=0.6.0 (from ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for stack_data>=0.6.0 from https://files.pythonhosted.org/packages/f1/7b/ce1eafaf1a76852e2ec9b22edecf1daa58175c090266e9f6c64afcd81d91/stack_data-0.6.3-py3-none-any.whl.metadata
#   Using cached stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting python-dateutil>=2.8.2 (from jupyter-client>=8.8.0->ipykernel)
#   Obtaining dependency information for python-dateutil>=2.8.2 from https://files.pythonhosted.org/packages/ec/57/56b9bcc3c9c6a792fcbaf139543cee77261f3651ca9da0c93f5c1221264b/python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting platformdirs>=2.5 (from jupyter-core!=6.0.*,>=5.1->ipykernel)
#   Obtaining dependency information for platformdirs>=2.5 from https://files.pythonhosted.org/packages/75/a6/a0a304dc33b49145b21f4808d763822111e67d1c3a32b524a1baf947b6e1/platformdirs-4.9.6-py3-none-any.whl.metadata
#   Using cached platformdirs-4.9.6-py3-none-any.whl.metadata (4.7 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.18.2->ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for parso<0.9.0,>=0.8.4 from https://files.pythonhosted.org/packages/b6/61/fae042894f4296ec49e3f193aff5d7c18440da9e48102c3315e1bc4519a7/parso-0.8.6-py2.py3-none-any.whl.metadata
#   Using cached parso-0.8.6-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for wcwidth from https://files.pythonhosted.org/packages/68/5a/199c59e0a824a3db2b89c5d2dade7ab5f9624dbf6448dc291b46d5ec94d3/wcwidth-0.6.0-py3-none-any.whl.metadata
#   Using cached wcwidth-0.6.0-py3-none-any.whl.metadata (30 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->jupyter-client>=8.8.0->ipykernel)
#   Obtaining dependency information for six>=1.5 from https://files.pythonhosted.org/packages/b7/ce/149a00dd41f10bc29e5921b496af8b574d8413afcd5e30dfa0ed46c2cc5e/six-1.17.0-py2.py3-none-any.whl.metadata
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for executing>=1.2.0 from https://files.pythonhosted.org/packages/c1/ea/53f2148663b321f21b5a606bd5f191517cf40b7072c0497d3c92c4a13b1e/executing-2.2.1-py2.py3-none-any.whl.metadata
#   Using cached executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for asttokens>=2.1.0 from https://files.pythonhosted.org/packages/d2/39/e7eaf1799466a4aef85b6a4fe7bd175ad2b1c6345066aa33f1f58d4b18d0/asttokens-3.0.1-py3-none-any.whl.metadata
#   Using cached asttokens-3.0.1-py3-none-any.whl.metadata (4.9 kB)
# Collecting pure-eval (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel)
#   Obtaining dependency information for pure-eval from https://files.pythonhosted.org/packages/8e/37/efad0257dc6e593a18957422533ff0f87ede7c9c6ea010a2177d738fb82f/pure_eval-0.2.3-py3-none-any.whl.metadata
#   Using cached pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached ipykernel-7.2.0-py3-none-any.whl (118 kB)
# Using cached comm-0.2.3-py3-none-any.whl (7.3 kB)
# Using cached debugpy-1.8.20-cp312-cp312-win_amd64.whl (5.4 MB)
# Using cached ipython-9.12.0-py3-none-any.whl (625 kB)
# Using cached jupyter_client-8.8.0-py3-none-any.whl (107 kB)
# Using cached jupyter_core-5.9.1-py3-none-any.whl (29 kB)
# Using cached matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached packaging-26.0-py3-none-any.whl (74 kB)
# Using cached psutil-7.2.2-cp37-abi3-win_amd64.whl (137 kB)
# Using cached pyzmq-27.1.0-cp312-abi3-win_amd64.whl (619 kB)
# Using cached tornado-6.5.5-cp39-abi3-win_amd64.whl (448 kB)
# Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Using cached colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Using cached ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Using cached platformdirs-4.9.6-py3-none-any.whl (21 kB)
# Using cached prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Using cached pygments-2.20.0-py3-none-any.whl (1.2 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Using cached asttokens-3.0.1-py3-none-any.whl (27 kB)
# Using cached executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Using cached parso-0.8.6-py2.py3-none-any.whl (106 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Using cached wcwidth-0.6.0-py3-none-any.whl (94 kB)
# Installing collected packages: pure-eval, wcwidth, traitlets, tornado, six, pyzmq, pygments, psutil, platformdirs, parso, packaging, nest-asyncio, executing, decorator, debugpy, comm, colorama, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jupyter-core, jedi, ipython-pygments-lexers, jupyter-client, ipython, ipykernel
#   Attempting uninstall: pure-eval
#     Found existing installation: pure_eval 0.2.3
#     Uninstalling pure_eval-0.2.3:
#       Successfully uninstalled pure_eval-0.2.3
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.6.0
#     Uninstalling wcwidth-0.6.0:
#       Successfully uninstalled wcwidth-0.6.0
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.14.3
#     Uninstalling traitlets-5.14.3:
#       Successfully uninstalled traitlets-5.14.3
#   Attempting uninstall: tornado
#     Found existing installation: tornado 6.5.5
#     Uninstalling tornado-6.5.5:
#       Successfully uninstalled tornado-6.5.5
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\DomingosCesar\\Documents\\GitHub\\aiml\\.venv\\Lib\\site-packages\\~ornado\\speedups.pyd'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
