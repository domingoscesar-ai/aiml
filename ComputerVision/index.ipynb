# %%
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img = cv.imread('data/img/domingos.png')
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img_rgb)
plt.axis('off') # Ativa e desativa os eixos com (on ou off), por padrao e on.
plt.tight_layout()
plt.show()
